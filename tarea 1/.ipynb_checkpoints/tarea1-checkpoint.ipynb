# %% [markdown]
# # Tarea 1: DS Lab
# - Ricardo Arancibia
# - José Díaz
# - Javier Santibáñez

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /home/jose/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ## P1

# %%
df_all = pd.read_csv('data/raw/w{}/metrocuadrado_all_w{}.csv'.format(str(13),str(13)))
for NN in range(14,18):
    direc = 'data/raw/w{}/metrocuadrado_all_w{}.csv'.format(str(NN),str(NN))
    df_aux = pd.read_csv(direc)
    # df_all.merge(df_aux)
    df_all = pd.concat([df_all,df_aux], ignore_index= True)
#df_all['Archivo'] = 'all' 
df_all.drop_duplicates(inplace=True, ignore_index= True)
print(df_all.shape)
df_all.head()
# Out:
# (16295, 8)
#                     property_type|rent_type|location       price n_rooms  \
# 0    Casa en Arriendo, LA SOLEDAD NORTE Bogotá D.C..  $1.050.000       3
# 1  Casa en Arriendo, CIUDAD SALITRE SUR-ORIENTAL ...  $3.930.000       3
# 2  Casa en Arriendo, VILLA DE LOS ALPES II SECTOR...    $750.000       3
# 3        Casa en Arriendo, PARIS GAITAN Bogotá D.C..  $3.400.000       5
# 4  Casa en Arriendo, BALCONES DE ORIENTE Bogotá D...  $1.560.000       4
#
#   n_bath   surface                                            details  \
# 0      2   63.0 m2  Excelente casa cerca de la calle 80 y Avenida ...
# 1      2  100.0 m2  Se arrienda casa bonita totalmente amoblada co...
# 2      1   90.0 m2  CASA DE TRES NIVELES TRES ALCOBAS SALA COMEDOR...
# 3      4   71.0 m2  casa ezquinera excelente ubicacion cinco alcob...
# 4      3   96.0 m2  Excelente casa de tres niveles, buena ubicació...
#
#                                                  url  metrocuadrado_index
# 0  https://www.metrocuadrado.com/inmueble/arriend...                 25.6
# 1  https://www.metrocuadrado.com/inmueble/arriend...                 57.3
# 2  https://www.metrocuadrado.com/inmueble/arriend...                 12.2
# 3  https://www.metrocuadrado.com/inmueble/arriend...                 56.0
# 4  https://www.metrocuadrado.com/inmueble/arriend...                 47.1

# %%
df_fur = pd.read_csv('data/raw/w{}/metrocuadrado_furnished_w{}.csv'.format(str(13),str(13)))
for NN in range(14,18):
    direc = 'data/raw/w{}/metrocuadrado_furnished_w{}.csv'.format(str(NN),str(NN))
    df_aux = pd.read_csv(direc)
    # df_fur.merge(df_aux)
    df_fur = pd.concat([df_fur,df_aux], ignore_index= True)
#df_fur['Archivo'] = 'furnished'
df_fur.drop_duplicates(inplace=True, ignore_index= True)
print(df_fur.shape)
df_fur.head()
# Out:
# (2099, 8)
#                     property_type|rent_type|location         price  n_rooms  \
# 0  Casa en Arriendo, CIUDAD SALITRE SUR-ORIENTAL ...    $3.930.000      3.0
# 1  Casa en Venta Y Arriendo, BELLAVISTA Bogotá D.C..    $1.300.000      3.0
# 2  Casa en Arriendo, PORTALES DEL NORTE Bogotá D.C..    $1.800.000      3.0
# 3  Casa en Venta Y Arriendo, SANTA SOFIA Bogotá D...    $1.500.000      5.0
# 4  Casa en Venta Y Arriendo, URBANIZACION SABANA ...  $145.000.000      3.0
#
#    n_bath   surface                                            details  \
# 0     2.0  100.0 m2  Se arrienda casa bonita totalmente amoblada co...
# 1     2.0   72.0 m2  hermosa casa en venta y en arriendo en, mandal...
# 2     3.0  76.81 m2  Estrato 4. CASA TRIPLEX!! Exterior . Cuenta co...
# 3     3.0  76.22 m2  Casa en Santa Sofia, excelente ubicación sobre...
# 4     2.0   77.0 m2  Casa esquinera, de tres niveles, se venden mue...
#
#                                                  url  metrocuadrado_index
# 0  https://www.metrocuadrado.com/inmueble/arriend...                 57.3
# 1  https://www.metrocuadrado.com/inmueble/venta-c...                 41.4
# 2  https://www.metrocuadrado.com/inmueble/arriend...                 41.3
# 3  https://www.metrocuadrado.com/inmueble/venta-c...                 34.2
# 4  https://www.metrocuadrado.com/inmueble/venta-c...                 62.5

# %%
keys = ['metrocuadrado_index','details','price','surface','url']
col = keys# + ['Archivo']
#print(col)
df = pd.merge(df_all, df_fur, how = 'outer', on = keys, indicator=True)

df['property_type|rent_type|location_x'].fillna(df['property_type|rent_type|location_y'])
df['n_rooms_x'].fillna(df['n_rooms_y'])
df['n_bath_x'].fillna(df['n_bath_y'])

df.drop(['property_type|rent_type|location_y', 'n_rooms_y', 'n_bath_y'], inplace=True, axis=1)

df.rename(columns={'property_type|rent_type|location_x':'property_type|rent_type|location',
                   'n_rooms_x':'n_rooms',
                   'n_bath_x':'n_bath',
                   '_merge':'furnished'}, inplace=True)

miss = df[df['furnished'].str.contains('right')]
df['furnished'] = ~df['furnished'].str.contains(pat = 'left')

print(df.shape)
df.head()
# Out:
# (16303, 9)
#                     property_type|rent_type|location       price n_rooms  \
# 0    Casa en Arriendo, LA SOLEDAD NORTE Bogotá D.C..  $1.050.000       3
# 1  Casa en Arriendo, CIUDAD SALITRE SUR-ORIENTAL ...  $3.930.000       3
# 2  Casa en Arriendo, VILLA DE LOS ALPES II SECTOR...    $750.000       3
# 3        Casa en Arriendo, PARIS GAITAN Bogotá D.C..  $3.400.000       5
# 4  Casa en Arriendo, BALCONES DE ORIENTE Bogotá D...  $1.560.000       4
#
#   n_bath   surface                                            details  \
# 0      2   63.0 m2  Excelente casa cerca de la calle 80 y Avenida ...
# 1      2  100.0 m2  Se arrienda casa bonita totalmente amoblada co...
# 2      1   90.0 m2  CASA DE TRES NIVELES TRES ALCOBAS SALA COMEDOR...
# 3      4   71.0 m2  casa ezquinera excelente ubicacion cinco alcob...
# 4      3   96.0 m2  Excelente casa de tres niveles, buena ubicació...
#
#                                                  url  metrocuadrado_index  \
# 0  https://www.metrocuadrado.com/inmueble/arriend...                 25.6
# 1  https://www.metrocuadrado.com/inmueble/arriend...                 57.3
# 2  https://www.metrocuadrado.com/inmueble/arriend...                 12.2
# 3  https://www.metrocuadrado.com/inmueble/arriend...                 56.0
# 4  https://www.metrocuadrado.com/inmueble/arriend...                 47.1
#
#    furnished
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False

# %%
miss
# Out:
#       property_type|rent_type|location       price n_rooms n_bath   surface  \
# 16295                              NaN  $3.750.000     NaN    NaN  117.0 m2
# 16296                              NaN  $2.300.000     NaN    NaN   50.0 m2
# 16297                              NaN  $1.950.000     NaN    NaN   50.0 m2
# 16298                              NaN  $2.300.000     NaN    NaN   48.0 m2
# 16299                              NaN  $2.600.000     NaN    NaN   60.0 m2
# 16300                              NaN  $1.750.000     NaN    NaN   48.0 m2
# 16301                              NaN  $3.900.000     NaN    NaN  102.0 m2
# 16302                              NaN  $2.525.000     NaN    NaN  106.0 m2
#
#                                                  details  \
# 16295  Hermosa casa amoblada en arriendo ubicada en e...
# 16296  Chicó Parque 93, excelente apartamento AMOBLAD...
# 16297  apartamento totalmente amoblado, muy bien ubic...
# 16298  Arriendo apartamento amoblado nuevo moderno ti...
# 16299  Se arrienda precioso apartamento amoblado, con...
# 16300  Apartamentototalmente  amoblado de 47 metros c...
# 16301  Hermoso y acogedor apartamento completamente a...
# 16302  Hermoso apartamento de 106m2  2  añoS de const...
#
#                                                      url  metrocuadrado_index  \
# 16295  https://www.metrocuadrado.com/inmueble/arriend...                 66.4
# 16296  https://www.metrocuadrado.com/inmueble/arriend...                 45.5
# 16297  https://www.metrocuadrado.com/inmueble/arriend...                 62.3
# 16298  https://www.metrocuadrado.com/inmueble/arriend...                 72.7
# 16299  https://www.metrocuadrado.com/inmueble/arriend...                 63.4
# 16300  https://www.metrocuadrado.com/inmueble/arriend...                 39.4
# 16301  https://www.metrocuadrado.com/inmueble/arriend...                 51.6
# 16302  https://www.metrocuadrado.com/inmueble/arriend...                 44.4
#
#         furnished
# 16295  right_only
# 16296  right_only
# 16297  right_only
# 16298  right_only
# 16299  right_only
# 16300  right_only
# 16301  right_only
# 16302  right_only

# %%
df.dropna(subset=['price','n_rooms','n_bath','surface'], inplace=True)
df.reset_index(drop=True,inplace=True)
print(df.shape)
# Out:
# (16048, 9)

# %%
df['price'] = df['price'].apply(lambda x: x.replace('$','')).apply(lambda x: x.replace('.','')).astype(np.float64)
df['surface'] = df['surface'].apply(lambda x: x.replace('m2','')).astype(np.float64)
df['n_bath'] = df['n_bath'].apply(lambda x: x.replace('+','')).astype(np.int64)
df['n_rooms'] = df['n_rooms'].apply(lambda x: x.replace('+','')).astype(np.int64)

df.head()
# Out:
#                     property_type|rent_type|location      price  n_rooms  \
# 0    Casa en Arriendo, LA SOLEDAD NORTE Bogotá D.C..  1050000.0        3
# 1  Casa en Arriendo, CIUDAD SALITRE SUR-ORIENTAL ...  3930000.0        3
# 2  Casa en Arriendo, VILLA DE LOS ALPES II SECTOR...   750000.0        3
# 3        Casa en Arriendo, PARIS GAITAN Bogotá D.C..  3400000.0        5
# 4  Casa en Arriendo, BALCONES DE ORIENTE Bogotá D...  1560000.0        4
#
#    n_bath  surface                                            details  \
# 0       2     63.0  Excelente casa cerca de la calle 80 y Avenida ...
# 1       2    100.0  Se arrienda casa bonita totalmente amoblada co...
# 2       1     90.0  CASA DE TRES NIVELES TRES ALCOBAS SALA COMEDOR...
# 3       4     71.0  casa ezquinera excelente ubicacion cinco alcob...
# 4       3     96.0  Excelente casa de tres niveles, buena ubicació...
#
#                                                  url  metrocuadrado_index  \
# 0  https://www.metrocuadrado.com/inmueble/arriend...                 25.6
# 1  https://www.metrocuadrado.com/inmueble/arriend...                 57.3
# 2  https://www.metrocuadrado.com/inmueble/arriend...                 12.2
# 3  https://www.metrocuadrado.com/inmueble/arriend...                 56.0
# 4  https://www.metrocuadrado.com/inmueble/arriend...                 47.1
#
#    furnished
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False

# %%
new_columns = df['property_type|rent_type|location'].str.split(",", expand = True) 
df['property_type'] = new_columns[0].str.split("en", expand = True)[0].str.strip()
df['rent_type'] = new_columns[0].str.split("en ", expand = True)[1].str.strip()
df['location'] = new_columns[1].str.strip().str.slice(0,-13,1).str.upper()

df.drop(['property_type|rent_type|location'], axis=1, inplace=True)

df
# Out:
#            price  n_rooms  n_bath  surface  \
# 0      1050000.0        3       2     63.0
# 1      3930000.0        3       2    100.0
# 2       750000.0        3       1     90.0
# 3      3400000.0        5       4     71.0
# 4      1560000.0        4       3     96.0
# ...          ...      ...     ...      ...
# 16043   796550.0        1       1     35.0
# 16044  1650000.0        1       1     54.0
# 16045  1550000.0        1       2     56.0
# 16046  3000000.0        1       2     38.0
# 16047  2750000.0        1       2     57.0
#
#                                                  details  \
# 0      Excelente casa cerca de la calle 80 y Avenida ...
# 1      Se arrienda casa bonita totalmente amoblada co...
# 2      CASA DE TRES NIVELES TRES ALCOBAS SALA COMEDOR...
# 3      casa ezquinera excelente ubicacion cinco alcob...
# 4      Excelente casa de tres niveles, buena ubicació...
# ...                                                  ...
# 16043  APARTAESTUDIO EN CEDRITOS   MULTIFAMILIAR UPSA...
# 16044  Apartamento tipo loft, con muy buena luz, sala...
# 16045  ESPECTACULAR DUPLEX, APARTA-ESTUDIO, EXTERIOR,...
# 16046  Arriendo, lindo y confortable apartamento amob...
# 16047  Apartamento de una alcoba.   Edificio Naia (Ca...
#
#                                                      url  metrocuadrado_index  \
# 0      https://www.metrocuadrado.com/inmueble/arriend...                 25.6
# 1      https://www.metrocuadrado.com/inmueble/arriend...                 57.3
# 2      https://www.metrocuadrado.com/inmueble/arriend...                 12.2
# 3      https://www.metrocuadrado.com/inmueble/arriend...                 56.0
# 4      https://www.metrocuadrado.com/inmueble/arriend...                 47.1
# ...                                                  ...                  ...
# 16043  https://www.metrocuadrado.com/inmueble/arriend...                 41.6
# 16044  https://www.metrocuadrado.com/inmueble/arriend...                 64.5
# 16045  https://www.metrocuadrado.com/inmueble/arriend...                 42.2
# 16046  https://www.metrocuadrado.com/inmueble/arriend...                 76.8
# 16047  https://www.metrocuadrado.com/inmueble/arriend...                 81.1
#
#        furnished property_type rent_type                      location
# 0          False          Casa  Arriendo              LA SOLEDAD NORTE
# 1           True          Casa  Arriendo   CIUDAD SALITRE SUR-ORIENTAL
# 2          False          Casa  Arriendo  VILLA DE LOS ALPES II SECTOR
# 3          False          Casa  Arriendo                  PARIS GAITAN
# 4          False          Casa  Arriendo           BALCONES DE ORIENTE
# ...          ...           ...       ...                           ...
# 16043      False       Apartam  Arriendo               ACACIAS USAQUEN
# 16044      False       Apartam  Arriendo           NICOLÁS DE FEDERMÁN
# 16045      False       Apartam  Arriendo                  SAN PATRICIO
# 16046       True       Apartam  Arriendo         SANTA BARBARA CENTRAL
# 16047       True       Apartam  Arriendo               CHICO NORTE III
#
# [16048 rows x 11 columns]

# %%
""""
def get_upper(data):
    #print(data)
    upper = data.str.isupper()
    #print(upper)
    lis = []
    for i,d in enumerate(data):
        if upper[i]:
            lis.append(d)
    return lis

words = df['location'].str.split(" ", expand = True)
words.columns = map(str, words.columns)
df_upper = [" ".join(get_upper(words.iloc[i])[:-1]) for i in range(len(words))]
df_upper
""""
# Out:
#   File "<ipython-input-355-9bbd4b3b8f1a>", line 16
#     """"
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
df['price by m2'] = df['price']/df['surface']
df['url'][9]
# Out:
# 'https://www.metrocuadrado.com/inmueble/arriendo-casa-bogota-urbanizacion-azafranes-4-habitaciones-2-banos-1-garajes/4278-2315'

# %%
df['n_garajes'] = [ 0 if x.find('-garajes')==-1 else x[x.find('banos-')+6: x.find('-garajes')] for x in df['url']]

for i in range(10):
    print(df['url'][i], df['n_garajes'][i])
    
pd.unique(df['n_garajes'])
# Out:
# https://www.metrocuadrado.com/inmueble/arriendo-casa-bogota-la-soledad-norte-3-habitaciones-2-banos-1-garajes/35-M1919 1
# https://www.metrocuadrado.com/inmueble/arriendo-casa-bogota-ciudad-salitre-sur-oriental-3-habitaciones-2-banos-1-garajes/769-M2387196 1
# https://www.metrocuadrado.com/inmueble/arriendo-casa-bogota-villa-de-los-alpes-ii-sector-3-habitaciones-1-banos/BOSA-04551604 0
# https://www.metrocuadrado.com/inmueble/arriendo-casa-bogota-paris-gaitan-5-habitaciones-4-banos/OCHE-04552802 0
# https://www.metrocuadrado.com/inmueble/arriendo-casa-bogota-balcones-de-oriente-4-habitaciones-3-banos-1-garajes/943-M2386284 1
# https://www.metrocuadrado.com/inmueble/arriendo-casa-bogota-tibabuyes-3-habitaciones-2-banos/279-M2384273 0
# https://www.metrocuadrado.com/inmueble/arriendo-casa-bogota-paris-gaitan-4-habitaciones-4-banos-1-garajes/OCHE-04552801 1
# https://www.metrocuadrado.com/inmueble/arriendo-casa-bogota-portales-del-norte-4-habitaciones-2-banos-1-garajes/9825-M2383938 1
# https://www.metrocuadrado.com/inmueble/arriendo-casa-bogota-urbanizacion-bolivia-oriental-3-habitaciones-2-banos-1-garajes/MC2383692 1
# https://www.metrocuadrado.com/inmueble/arriendo-casa-bogota-urbanizacion-azafranes-4-habitaciones-2-banos-1-garajes/4278-2315 1
# array(['1', 0, '2', '4', '3', '4+'], dtype=object)

# %%
df['tipo_producto'] = np.zeros(len(df)) # categoria 0
indices=df.query('80<=surface <120 and property_type=="Casa"').index
df.loc[indices,'tipo_producto'] = 1
indices=df.query('120<=surface <180 and property_type=="Casa"').index
df.loc[indices,'tipo_producto'] = 2
indices=df.query('180<=surface <240 and property_type=="Casa"').index
df.loc[indices,'tipo_producto'] = 3
indices=df.query('240<=surface <360 and property_type=="Casa"').index
df.loc[indices,'tipo_producto'] = 4
indices=df.query('360<=surface <=460 and property_type=="Casa"').index
df.loc[indices,'tipo_producto'] = 5
indices=df.query('40<=surface <60 and property_type=="Apartam"').index
df.loc[indices,'tipo_producto'] = 6
indices=df.query('60<=surface <80 and property_type=="Apartam"').index
df.loc[indices,'tipo_producto'] = 7
indices=df.query('80<=surface <=120 and property_type=="Apartam"').index
df.loc[indices,'tipo_producto'] = 8

# %%
pd.unique(df['location'])
# Out:
# array(['LA SOLEDAD NORTE', 'CIUDAD SALITRE SUR-ORIENTAL',
#        'VILLA DE LOS ALPES II SECTOR', 'PARIS GAITAN',
#        'BALCONES DE ORIENTE', 'TIBABUYES', 'PORTALES DEL NORTE',
#        'URBANIZACION BOLIVIA ORIENTAL', 'URBANIZACION AZAFRANES',
#        'URBANIZACION EL CORTIJO', 'CAMPO ALEGRE', 'SANTA ANA ORIENTAL',
#        'HIPOTECHO II', 'MIRANDELA', 'COSTA AZUL', 'CANTALEJO',
#        'NORMANDIA OCCIDENTAL', 'LOS PANTANOS', 'BOSQUES DE MARIANA',
#        'BOSQUE DE PINOS', 'ESTACION VICTORIA', 'VILLA ALSACIA',
#        'BRITALIA', 'SAN JORGE', 'PRADO VERANIEGO NORTE',
#        'URBANIZACION TIBABUYES UNIVERSAL', 'EL TINTAL A.S.D.', 'TIMIZA',
#        'AUTOPISTA MUZU', 'HIPOTECHO III', 'BELLAVISTA', 'MOLINOS NORTE',
#        'CEDRO BOLIVAR', 'LA LIBERIA', 'LA GRANJA', 'NUEVA ZELANDIA',
#        'LA ISABELA', 'CAPELLANIA', 'VILLAS DE GRANADA I', 'BAVARIA',
#        'EL REDIL', 'ACACIAS', 'BARRANCAS NORTE', 'SANTA ANA OCCIDENTAL',
#        'URBANIZACION TINTALA', 'VALLADOLID', 'EL PLAN', 'SALITRE I',
#        'EL VERVENAL', 'TOBERIN', 'LA PRADERA', 'LA CATEDRAL',
#        'EL MORTIÑO', 'MUZU', 'VILLA DEL PRADO', 'AMERICAS OCCIDENTAL',
#        'GUIPARMA', 'LOS CEREZOS', 'CIUDAD JARDIN NORTE', 'PREDIO CALDAS',
#        'MARGARITAS OCCIDENTAL', 'MARRUECOS II SECTOR', 'SANTA TERESA',
#        'EL RINCON SANTO', 'LAS GALIAS', 'LA TRINIDAD', 'CEDRITOS',
#        'VILLA DEL RIO', 'MAZUREN', 'URBANIZACION LA GRAN GRANADA',
#        'VILLA DEL NORTE III', 'SANTA BARBARA',
#        'BERTHA HERNANDEZ DE OSPINA PER', 'RODESIA', 'PINOS DE LOMBARDIA',
#        'CEDRO SALAZAR', 'TUNJUELITO', 'SANTA HELENITA', 'BILBAO I SECTOR',
#        'GILMAR', 'VILLA MARIA', 'MONACO', 'SANTA BARBARA CENTRAL',
#        'LOS NARANJOS', 'MARCO FIDEL SUAREZ', 'MANDALAY II',
#        'CIUDAD TECHO', 'OSORIO XII', 'PRADERA NORTE', 'LA MACARENA',
#        'BOSQUE IZQUIERDO', 'MARIA PAZ', 'SAN CIPRIANO', 'BARRANCAS',
#        'EL RINCON DE LOS ANGELES', 'GALAN', 'VILLA RIOS', 'SANTA HELENA',
#        'ACACIAS USAQUEN', 'LA CAROLINA', 'EL PORVENIR', 'SUBA NARANJOS',
#        'SAN BERNARDINO', 'ESTRELLA DEL NORTE', 'VILLA MAGDALA',
#        'POTRERILLOS', 'JOSE MARIA CARBONELL', 'SAN FERNANDO', 'BOSCONIA',
#        'LAS MARGARITAS', 'VILLA DORADO NORTE', 'CALANDAIMA',
#        'URBANIZACION CARVAJAL', 'TEJARES DEL NORTE', 'FLORIDA BLANCA',
#        'SANTA SOFIA', 'CEDRO NARVAEZ', 'LA CHUCUA', '',
#        'BOGOTA PROTECHO II', 'URBANIZACION SABANA DE TIBABUYES',
#        'EL PALMAR', 'CAOBOS SALAZAR', 'EL RETAZO',
#        'URBANIZACION CIUDAD KENNEDY SU', 'URBANIZACION BOSQUES DE MEDINA',
#        'URBANIZACION EL DORADO', 'INDIA CATALINA', 'MADELENA II Y IV',
#        'LISBOA', 'VILLA NOVA', 'TIERRA LINDA', 'LAS CRUCES',
#        'URBANIZACION SANTA COLOMA', 'EL CONTADOR',
#        'VILLAS DEL MEDITERRANEO', 'LAS FLORES', 'EL TINTAL CENTRAL',
#        'TUNA ALTA', 'GRAN GRANADA', 'PRADO PINZON',
#        'SANTA BARBARA ORIENTAL', 'CASA BLANCA SUBA', 'VILLA CLAUDIA',
#        'USAQUEN', 'MARANTA III SECTOR', 'EL CEREZO', 'CANAPRO',
#        'LOS ANDES', 'LA PATRIA', 'POPULAR MODELO', 'EL SALITRE',
#        'PALOBLANCO', 'JULIO FLOREZ', 'ENTRERIOS', 'LAS ACASIAS',
#        'CONEJERA', 'LA TRIGUERA', 'POLO CLUB', 'CARMEN',
#        'CENTRO AMERICAS', 'CIUDAD BACHUE', 'LOS CEDROS ORIENTAL',
#        'NIZA SUBA', 'SANTA ROSA', 'SANTA CECILIA', 'SANTA ISABEL',
#        'SAN JOSE DE BAVARIA', 'PUENTE LARGO', 'MARSELLA', 'LA CALLEJA',
#        'JOSE JOAQUIN VARGAS', 'RESTREPO', 'VILLA LUZ', 'ALTOS DE SUBA',
#        'RAFAEL URIBE', 'PROVIVIENDA NORTE', 'JORGE CORTES',
#        'SANTA HELENA I', 'LA ESTRADITA', 'CIUDAD SALITRE OCCIDENTAL',
#        'MALLORCA', 'VERACRUZ', 'ALAMOS NORTE', 'ANTIGUO COUNTRY',
#        'EL ENCANTO', 'LA ESPAÑOLA', 'NORMANDIA', 'NA',
#        'MODELIA OCCIDENTAL', 'LA ESMERALDA', 'SAN JOSE DEL PRADO',
#        'SAN ANTONIO NOR - OCCIDENTAL', 'NIZA NORTE',
#        'AMERICAS SECTOR GALAN', 'RINCON DEL CHICO', 'LA ESPERANZA',
#        'ALAMOS', 'BELMIRA', 'CAMPIN OCCIDENTAL', 'AUTOPISTA MEDELLIN',
#        'SABANALARGA', 'ALCAZARES', 'PARQUE POPULAR SALITRE', 'IBERIA',
#        'BONANZA', 'EL BATAN', 'LOS CEDRITOS', 'SANTA BARBARA ALTA',
#        'LAS VILLAS', 'AMERICAS OCCIDENTAL II', 'PARQUES DE LORENA',
#        'BOYACA', 'ATENAS', 'BAQUERO', 'QUINTA PAREDES', 'LOS CEDROS',
#        'TORCA', 'PRINCESA BOCHICA', 'TUNALITO', 'EMAUS', 'SUBA URBANO',
#        'FOLEDO', 'CASA BLANCA', 'BOLIVIA', 'EL RINCON', 'SAN LUIS',
#        'SAN FRANCISCO', 'MOCHUELO NORTE', 'CONTADOR', 'LA NUEVA GLORIA',
#        'COUNTRY CLUB', 'URBANIZACION CORDOBA NIZA', 'ALCAZARES NORTE',
#        'QUINTA CAMACHO', 'PRADO VERANIEGO', 'LOURDES', 'SAN MIGUEL',
#        'LA CASTELLANA', 'LAS ORQUIDEAS', 'CLUB LOS LAGARTOS',
#        'CIUDAD QUIRIGUA', 'BANCO CENTRAL', 'GINEBRA NORTE',
#        'LAS AMERICAS', 'MARGARITAS I SECTOR', 'BALCARES',
#        'VILLAS DE GRANADA', 'GIRALDA', 'URBANIZACION AVENIDA DECIMA',
#        'NUEVA MARSELLA I', 'ZONA INDUSTRIAL', 'SANTA BIBIANA',
#        'SANTA BARBARA OCCIDENTAL', 'SAN FELIPE', 'LOS ROSALES',
#        'AMERICA OCCIDENTAL III', 'ESTORIL', 'MODELIA', 'SIETE DE AGOSTO',
#        'PASADENA', 'SAN GABRIEL NORTE', 'CHICO NORTE', 'LA SOLEDAD',
#        'CHICO NORTE III', 'CERROS DE LOS ALPES', 'SANTA CATALINA',
#        'LA VICTORIA', 'PALERMO', 'JARDINES DEL NORTE',
#        'URBANIZACION ALEJANDRO', 'ALOHA SECTOR SUR', 'SANTANDER',
#        'COMUNEROS', 'PRADO VERANIEGO SUR', 'BOSQUE DE MODELIA',
#        'EL NOGAL', 'CHAPINERO SUR OCCIDENTAL', 'SAN PATRICIO',
#        'SANTA TERESITA', 'CANODROMO', 'MARIA CRISTINA', 'SAN JOAQUIN',
#        'LA ESTRADA', 'ESCUELA MILITAR', 'RINCON DEL CEDRO', 'POTOSI',
#        'VICTORIA NORTE', 'LOS ANGELES', 'GARCES NAVAS ORIENTAL',
#        'URBANIZACION CIUDADELA COLSUBSIDIO', 'QUINTA RAMOS',
#        'JORGE ELIECER GAITAN', 'HIPOTECHO', 'NIZA CORDOBA',
#        'LOS ANDES NORTE', 'EL SOL', 'ALTOS DE CHOZICA',
#        'VILLEMAR FONTIBON', 'ALFONSO LOPEZ', 'GRAN AMERICA', 'VERAGUAS',
#        'PARDO RUBIO', 'CERROS DE SANTA BARBARA', 'ZONA FRANCA',
#        'LAGO GAITAN', 'LA VERACRUZ', 'BOSQUE POPULAR', 'LA FRAGUA',
#        'EL REFUGIO', 'LAS FERIAS OCCIDENTAL', 'SANTA ISABEL SUR',
#        'CONCEPCION NORTE', 'NIZA', 'LA COLINA CAMPESTRE', 'REMANSO',
#        'EL RECUERDO', 'A.J. SUCRE I', 'MARLY', 'RIONEGRO', 'BUENOS AIRES',
#        'URBANIZACION CASTILLA', 'TEUSAQUILLO', 'NUEVO CONTRY',
#        'EL RECREO DE LOS FRAILES', 'CHICO NORTE II', 'EL ESPARTILLAL',
#        'SIERRAS DEL MORAL', 'EL RETIRO', 'EL CEDRO', 'VIVEROS', 'CAJICA',
#        'PRADOS DEL SALITRE', 'LA IGUALDAD', 'ARMENIA', 'SAN DIEGO',
#        'LA CABAÑA', 'CENTRO NARIÑO', 'CENTENARIO', 'SAN JOSE',
#        'SAN CAYETANO', 'SAMPER MENDOZA', 'ONCE DE NOVIEMBRE',
#        'CIUDAD JARDIN SUR', 'ESTRELLA', 'EL SEMINARIO', 'LA MAGDALENA',
#        'LA SALLE', 'LA FLORIDA', 'NICOLAS DE FEDERMAN',
#        'BABARIA TECHO III', 'BOSTON', 'SAN ISIDRO', 'COLOMBIA',
#        'LA ACANADA', 'CENTRO FONTIBON', 'CENTRO ADMINISTRATIVO',
#        'BELLA SUIZA', 'CANDELARIA LA NUEVA II SECTOR', 'JARDIN BOTANICO',
#        'LUSITANIA', 'NIZA SUR', 'BOSQUE CALDERON', 'ACEVEDO TEJADA',
#        'SAGRADO CORAZON', 'REMANSO SUR', 'LA AURORA', 'EL PROGRESO',
#        'CHAPINERO NORTE', 'CLARET', 'CHICO', 'INGLES', 'LA CAMELIA',
#        'BOSQUES DEL MARQUEZ', 'GIRARDOT', 'LA MERCED', 'LA CONCORDIA',
#        'QUINTA MUTIS', 'FLORIDA BLANCA NORTE', 'LA MERCED NORTE',
#        'CIUDADELA REAL', 'BOSQUES DE PINO', 'COLINA', 'GUAYMARAL',
#        'RICAURTE', 'ANDES NORTE', '0', 'BELALCAZAR', 'SUCRE', 'JAZMIN',
#        'SAMPER', 'LA SURENA', 'LA PORCIUNCULA',
#        'URBANIZACION TECHO BAVARIA', 'GINEBRA', 'LA CAPUCHINA',
#        'LA CAPILLA', 'LA CABRERA', 'SIERRAS DE MORAL',
#        'EL CARMEN FONTIBON', 'CASABLANCA SUBA', 'NUEVA MARSELLA III',
#        'CHAPINERO CENTRAL', 'LAS ACACIAS', 'SAN MARTIN', 'LAS NIEVES',
#        'VILLA ALSACIA 2', 'QUESADA', 'COLSEGUROS',
#        'URBANIZACION TURINGIA', 'LA ESPERANZA NORTE',
#        'LA CAMPIÑA I SECTOR', 'CIUDAD SALITRE NOR-ORIENTAL',
#        'MINUTO DE DIOS', 'EL CODITO', 'EL CAMPIN', 'SIMON BOLIVAR',
#        'LAS AGUAS', 'PARQUE RESIDENCIA NUEVO SUBA',
#        'URBANIZACION CORDOBA', 'CATALUNA', 'ALCALA', 'LA FAVORITA',
#        'SEARS', 'LA EMILIA', 'CEDRO MADEIRAS', 'PAULO VI NORTE',
#        'LA LIBERTAD', 'PARIS', 'SAN FERNANDO OCCIDENTAL', 'INGEMAR',
#        'PLENITUD', 'SANTA FE', 'NARIÑO SUR', 'TIBANA',
#        'SAN CRISTOBAL SUR', 'EGIPTO', 'CONJUNTO RESIDENCIAL EL BOSQUE',
#        'EL CONDADO DE LA PAZ', 'SAN CRISTOBAL NORTE', 'OLAYA',
#        'NUEVA GRANADA', 'BOSQUE CALDERON TEJADA', 'EL TRIUNFO',
#        'JARDIN DEL NORTE', 'LA FELICIDAD', 'SANTA MARIA', 'OLARTE',
#        'EL LISTON', 'AUTOPISTA MUZU 0RIENTAL', 'EL LAUREL',
#        'BENJAMIN HERRERA', 'TAPETE', 'SANTA MATILDE', 'TUNA',
#        'EL MORISCO', 'QUIROGA CENTRAL', 'CALVO SUR',
#        'BOCHICA PRIMER SECTOR', 'PRADOS DE LA CALLEJA', 'LA ALAMEDA',
#        'BELEN', 'SALAZAR GOMEZ', 'COLON', 'VERSALLES', 'METROPOLIS',
#        'ESCUELA DE INFANTERIA', 'EL PORTAL', 'EL TINTAL', 'TIBABITA',
#        'SAN BERNARDO', 'JOSE ANTONIO GALAN', 'CHAPINERO ALTO',
#        'URBANIZACION BENGALA', 'EL PINO', 'SAN VICTORINO', 'SUBA',
#        'URBANIZACION BOCHICA I - II', 'CHICO NORTE II SECTOR',
#        'URBANIZACION BOCHICA III - IV', 'CHICO NORTE III SECTOR',
#        'GALERIAS', 'TIMIZA A', 'EL CHICO', 'LOS CEDROS-USAQUÉN',
#        'CHICO NAVARRA', 'BOCHICA II', 'BOSQUE DE PINOS I',
#        'VILLA MAYOR ORIENTAL', 'CHICO RESERVADO', 'NICOLÁS DE FEDERMÁN',
#        'CHICÓ NORTE', 'EL ROLIN', 'MORABIA', 'JERICO', 'GRANADA NORTE',
#        'LA ALQUERIA', 'SAN ANTONIO NORTE', 'LAGUNETA', 'SAN BASILIO',
#        'DOCE DE OCTUBRE', 'SOCIEGO SUR', 'RESTREPO OCCIDENTAL',
#        'PUENTE ARANDA', 'UNIDAD CARABELAS', 'EL DORADO', 'LA FRAGUITA',
#        'MILENTA', 'BOCHICA', 'MILLAN', 'PRIMAVERA OCCIDENTAL',
#        'URBANIZACION CIUDAD BACHUE II', 'URBANIZACION CASTILLA LA NUEVA',
#        'SAN EUSEBIO', 'PLAYAS DE JABOQUE', 'LAGO DE SUBA', 'VILLA INES',
#        'LAS FERIAS', 'NUEVO MUZU', 'LAS MERCEDES', 'H.B.', 'LA ASUNCION',
#        'EL ROSARIO', 'URBANIZACION CASTILLA REAL', 'EL RUBI',
#        'CINCO DE NOVIEMBRE', 'BOGOTÁ D.C.', 'URBANIZACION SANTA CECILIA',
#        'LA ESPERANZA SUR', 'LOMBARDIA', 'TURINGIA II', 'BRASILIA',
#        'FLORENCIA', 'SAN ANTONIO DE PADUA', 'SAN CARLOS',
#        'AUTOPISTA DEL SUR', 'VENECIA', 'GRAN BRITALIA I', 'EL PAÑUELITO',
#        'NARANJOS', 'LOS EJIDOS', 'RINCON DE SANTA PAULA', 'EL JARDIN',
#        'CEDRO GOLF', 'EL CONTADOR-USAQUÉN', 'SOCIEGO', 'FERROCAJA',
#        'PORCIUNCULA', 'BOSQUES DE SAN JORGE', 'OSPINA PEREZ SUR',
#        'EDUARDO SANTOS', 'PARDO RUBIO NOROCCIDENTAL',
#        'RINCON DE MANDALAY', 'EL VERGEL OCCIDENTAL', 'SUPER MANZANA 6',
#        'MONTERREY', 'BOSQUE DE PINOS USAQUEN', 'ESPARTILLAL',
#        '20 DE JULIO', 'BOSQUE DE PINOS III', 'GRANADA',
#        'CHAPINERO OCCIDENTAL', 'SAN JOSE DE USAQUEN', 'VILLA DEL MAR',
#        'VILLAS DEL MADRIGAL', 'TIBABUYES II', 'URBANIZACION EL PARQUE',
#        'ARBORIZADORA BAJA', 'HIPODROMO DE TECHO II', 'ATAHUALPA',
#        'LOS MONJES', 'JUAN XXIII', 'EL CONDOR', 'BATAN',
#        'SANTA BARBARA CENTRAL-USAQUÉN', 'SUPER MANZANA 9B', 'CANTAGALLO',
#        'LA PAZ', 'CARACAS', 'CIUDAD BERNA', 'CALLEJA', 'RINCON DEL NORTE',
#        'VILLA SAGRARIO', 'NUEVO KENNEDY', 'LAGO TIMIZA I',
#        'URBANIZACION PARQUE METROPOLIT.', 'ESTACION CENTRAL', 'JERUSALEN',
#        'SAN JAVIER', 'VILLA ELISA', 'COFRADIA', 'LA PERSEVERANCIA',
#        'CENTRO INDUSTRIAL', 'SAN JOSE DE LA GRANJA',
#        'SANTA FE DEL TINTAL', 'TUNA BAJA', 'PAULO VI', 'ALMENDROS NORTE',
#        'GARCES NAVES OCCIDENTAL', 'LA PRIMAVERA',
#        'MULTIFAMILIARES LA PAZ', 'CLUB DE LOS LAGARTOS',
#        'URBANIZACION SINAI', 'LIBANO', 'PORTAL DE LAS MERCEDES',
#        'SUPER MANZANA 3', 'GUSTAVO RESTREPO', 'SABANA GRANDE',
#        'URBANIZACION TUNDAMA 1', 'SUPER MANZANA 7', 'BILBAO II SECTOR',
#        'EL TEJAR', 'CIUDAD VILLAMAYOR ANTIGUA', 'SANTIAGO PEREZ',
#        'SAN MARTIN DE PORRES I Y II', 'SEVILLA', 'I SECTOR', 'COCADAS',
#        'LIBERTADOR', 'POLICARPA SALAVARRETA', 'LUNAPARK', 'EL MORAL'],
#       dtype=object)

# %%
# 5
df_upz = pd.read_csv('data/asignacion_upz/barrio-upz.csv')
print(df_upz.shape)
df_upz
# Out:
# (468, 5)
#     UPlCodigo  UPlTipo          UPlNombre       UPlArea   pro_location
# 0      UPZ100        1           GALERIAS  2.375681e+06        palermo
# 1      UPZ100        1           GALERIAS  2.375681e+06     belalcazar
# 2      UPZ100        1           GALERIAS  2.375681e+06          sears
# 3      UPZ100        1           GALERIAS  2.375681e+06       galerias
# 4      UPZ100        1           GALERIAS  2.375681e+06  banco central
# ..        ...      ...                ...           ...            ...
# 463     UPZ42        1            VENECIA  6.638420e+06     nuevo muzu
# 464     UPZ42        1            VENECIA  6.638420e+06      el condor
# 465     UPZ42        1            VENECIA  6.638420e+06       laguneta
# 466     UPZ52        1           LA FLORA  1.877160e+06    villa maria
# 467     UPZ60        1  PARQUE ENTRENUBES  4.190395e+06            NaN
#
# [468 rows x 5 columns]

# %%
pd.unique(df_upz['UPlNombre'])
# Out:
# array(['GALERIAS', 'LAS MARGARITAS', 'QUINTA PAREDES', 'TEUSAQUILLO',
#        'SAGRADO CORAZON', 'GRAN BRITALIA', 'ZONA INDUSTRIAL', 'FONTIBON',
#        'DOCE DE OCTUBRE', 'MODELIA', 'PARQUE SALITRE', 'JARDIN BOTANICO',
#        'EL REFUGIO', 'SUBA', 'BOLIVIA', 'COUNTRY CLUB', 'SANTA BARBARA',
#        'LOS ANDES', 'SAN ISIDRO - PATIOS', 'LA ESMERALDA', 'EL PORVENIR',
#        'PATIO BONITO', 'CHAPINERO', 'CIUDAD SALITRE ORIENTAL',
#        'PARDO RUBIO', 'SOSIEGO', 'PUENTE ARANDA', 'LA SABANA', 'CARVAJAL',
#        'LAS NIEVES', 'SANTA ISABEL', 'APOGEO', 'EL PRADO', 'NIZA',
#        'CASA BLANCA SUBA', 'CIUDAD SALITRE OCCIDENTAL',
#        'PARQUE SIMON BOLIVAR - CAN', 'SANTA CECILIA', 'EL TESORO',
#        'MONTE BLANCO', 'TIBABUYES', 'MINUTO DE DIOS',
#        'FONTIBON SAN PABLO', 'GUAYMARAL', 'CORABASTOS', 'LUCERO',
#        'EL MOCHUELO', 'DIANA TURBAY', 'LOS LIBERTADORES', 'DANUBIO',
#        'ARBORIZADORA', 'LA ACADEMIA', 'SAN JOSE DE BAVARIA', 'BRITALIA',
#        'LAS FERIAS', 'CAPELLANIA', 'LA GLORIA', 'LA ALHAMBRA',
#        'CALANDAIMA', 'TOBERIN', 'LA URIBE', 'ALFONSO LOPEZ', 'COMUNEROS',
#        'SAN RAFAEL', 'KENNEDY CENTRAL', 'TIMIZA', 'BAVARIA', 'AMERICAS',
#        'LOS CEDROS', 'JERUSALEM', 'SAN JOSE', 'SAN FRANCISCO',
#        'GRAN YOMASA', 'SAN CRISTOBAL NORTE', 'USAQUEN', 'GARCES NAVAS',
#        'ENGATIVA', 'LA FLORESTA', 'CHICO LAGO', 'LOS ALCAZARES',
#        'LOURDES', 'LA MACARENA', 'LA CANDELARIA', 'VERBENAL', 'EL RINCON',
#        'BOYACA REAL', 'ALAMOS', 'CIUDAD JARDIN', 'RESTREPO', 'MUZU',
#        'CIUDAD MONTES', '20 DE JULIO', 'BOSA OCCIDENTAL', 'BOSA CENTRAL',
#        'SAN BLAS', 'LAS CRUCES', 'TINTAL SUR',
#        'PASEO DE LOS LIBERTADORES', 'CASTILLA', 'GRANJAS DE TECHO',
#        'TINTAL NORTE', 'AEROPUERTO EL DORADO', 'ZONA FRANCA', 'MARRUECOS',
#        'QUIROGA', 'TUNJUELITO', 'MARCO FIDEL SUAREZ', 'ISMAEL PERDOMO',
#        'CIUDAD USME', 'VENECIA', 'LA FLORA', 'PARQUE ENTRENUBES'],
#       dtype=object)

# %%
df_upz['pro_location'] = df_upz['pro_location'].str.upper()
pd.unique(df_upz['pro_location'])
# Out:
# array(['PALERMO', 'BELALCAZAR', 'SEARS', 'GALERIAS', 'BANCO CENTRAL',
#        'EL CAMPIN', 'SAN JOSE', 'LAS MARGARITAS', 'CENTRO NARIÑO',
#        'GRAN AMERICA', 'ACEVEDO TEJADA', 'EL RECUERDO', 'QUINTA PAREDES',
#        'SALITRE I', 'ARMENIA', 'LA VICTORIA', 'CANTAGALLO',
#        'CENTRO ADMINISTRATIVO', 'LA SOLEDAD', 'SANTA TERESA',
#        'SANTA TERESITA', 'LA MACARENA', 'BOGOTÁ D.C.', 'SAN MARTIN',
#        'LA MERCED', 'SAMPER', 'LA CAPUCHINA', 'SAGRADO CORAZON',
#        'GRAN BRITALIA I', 'BRITALIA', 'ESTACION CENTRAL',
#        'ZONA INDUSTRIAL', 'AMERICAS OCCIDENTAL', 'I SECTOR',
#        'VILLEMAR FONTIBON', 'CENTENARIO', 'EL CARMEN FONTIBON', 'CARMEN',
#        'GRANADA', 'COFRADIA', 'CENTRO FONTIBON', 'BOSTON', 'VERSALLES',
#        'ATAHUALPA', 'EL SALITRE', 'POPULAR MODELO', 'TAPETE', 'ESTRELLA',
#        'DOCE DE OCTUBRE', 'JORGE ELIECER GAITAN', 'SAN FERNANDO',
#        'ESCUELA MILITAR', 'CAPELLANIA', 'MODELIA OCCIDENTAL', 'MODELIA',
#        'MALLORCA', 'PLENITUD', 'LAGO GAITAN', 'PARQUE POPULAR SALITRE',
#        'EL NOGAL', 'EL RETIRO', 'BOSQUES DE SAN JORGE', 'TUNA ALTA',
#        'TURINGIA II', 'LAS FLORES', 'TUNA', 'TUNA BAJA', 'ACACIAS',
#        'SUBA', 'TIBABUYES II', 'TIBABUYES', 'PINOS DE LOMBARDIA',
#        'PORTAL DE LAS MERCEDES', 'BOCHICA II', 'BOLIVIA', 'LOS CEDROS',
#        'LOS NARANJOS', 'NARANJOS', 'LOS CEREZOS', 'CIUDADELA REAL',
#        'LA CAROLINA', 'CALLEJA', 'LA CALLEJA', 'MOLINOS NORTE',
#        'CAMPO ALEGRE', 'CHICO NAVARRA', 'EL PORVENIR', 'SAN PATRICIO',
#        'SANTA BARBARA OCCIDENTAL', 'SANTA BARBARA CENTRAL-USAQUÉN',
#        'ENTRERIOS', 'LA CASTELLANA', 'RIONEGRO', 'ANDES NORTE',
#        'LOS ANDES NORTE', 'SAN LUIS', 'FLORENCIA', 'NICOLÁS DE FEDERMÁN',
#        'NICOLAS DE FEDERMAN', 'PAULO VI', 'LA CABAÑA',
#        'LOS CEDROS ORIENTAL', 'SANTA SOFIA', 'JAZMIN', 'MARLY', 'QUESADA',
#        'CHAPINERO CENTRAL', 'CHAPINERO NORTE', 'LOURDES', 'CONEJERA',
#        'SUCRE', nan, 'BOSQUE CALDERON', 'INGEMAR', 'LA SALLE', 'EMAUS',
#        'CHAPINERO ALTO', 'BUENOS AIRES', 'SAN JAVIER', 'QUINTA RAMOS',
#        'NARIÑO SUR', 'CALVO SUR', 'SALAZAR GOMEZ', 'CENTRO INDUSTRIAL',
#        'RESTREPO OCCIDENTAL', 'MONTERREY', 'LA FAVORITA', 'EL LISTON',
#        'RICAURTE', 'SAMPER MENDOZA', 'COLSEGUROS', 'VENECIA', 'TIMIZA',
#        'SAN VICTORINO', 'LA VERACRUZ', 'VERACRUZ', 'MONACO', 'LAS NIEVES',
#        'VILLA MENDOZA', 'EDUARDO SANTOS', 'LA LIBERIA',
#        'SANTA ISABEL SUR', 'SANTA ISABEL', 'OLARTE', 'VILLA DEL RIO',
#        'ALCALA', 'COSTA AZUL', 'SANTA HELENA', 'SANTA HELENA I',
#        'VICTORIA NORTE', 'MAZUREN', 'NIZA SUR', 'PRADO VERANIEGO',
#        'PRADO VERANIEGO SUR', 'NIZA NORTE', 'NIZA', 'NIZA SUBA',
#        'NIZA CORDOBA', 'SAN JORGE', 'LAS VILLAS', 'LA COLINA CAMPESTRE',
#        'CIUDAD JARDIN NORTE', 'IBERIA', 'CASABLANCA SUBA',
#        'LA ESPERANZA SUR', 'TEUSAQUILLO', 'NORMANDIA',
#        'NORMANDIA OCCIDENTAL', 'SANTA CECILIA', 'EL ENCANTO',
#        'LOS MONJES', 'VILLA LUZ', 'SAN JOAQUIN', 'LISBOA',
#        'ALTOS DE SUBA', 'CHICO RESERVADO', 'MINUTO DE DIOS',
#        'CASA BLANCA', 'PARIS GAITAN', 'EL MORISCO', 'PARIS', 'EL SOL',
#        'CIUDAD QUIRIGUA', 'CIUDAD BACHUE I', 'CIUDAD BACHUE',
#        'MARIA CRISTINA', 'EL PALMAR', 'JERICO', 'EL REFUGIO', 'MARIA PAZ',
#        'LA ALAMEDA', 'SAN MIGUEL', 'LA PAZ', 'LA NUEVA GLORIA',
#        'ARBORIZADORA BAJA', 'MADELENA II Y IV', 'EL SEMINARIO',
#        'VILLA DEL PRADO', 'NUEVA ZELANDIA', 'MIRANDELA', 'CANTALEJO',
#        'GILMAR', 'URBANIZACION CORDOBA', 'JARDINES DEL NORTE',
#        'JARDIN DEL NORTE', 'GRANADA NORTE', 'LA ESTRADITA', 'LA ESTRADA',
#        'METROPOLIS', 'LAS FERIAS OCCIDENTAL', 'LAS FERIAS', 'BONANZA',
#        'BOSQUE POPULAR', 'EL ROLIN', 'FERROCAJA',
#        'URBANIZACION EL PARQUE', 'EL PINO', 'ESTORIL', 'PASADENA',
#        'PUENTE LARGO', 'CASA BLANCA SUBA', 'JORGE CORTES', 'EL BATAN',
#        'BATAN', 'MULTIFAMILIARES LA PAZ', 'CALANDAIMA',
#        'SANTA FE DEL TINTAL', 'BALCONES DE ORIENTE', 'LAS ORQUIDEAS',
#        'LA PRIMAVERA', 'PRADERA NORTE', 'LA PRADERA', 'VILLA MAGDALA',
#        'TOBERIN', 'SAN DIEGO', 'CANAPRO', 'EL REDIL', 'ALFONSO LOPEZ',
#        'COMUNEROS', 'LA ESPAÑOLA', 'EL PLAN', 'MILENTA',
#        'PROVIVIENDA NORTE', 'GALAN', 'PUENTE ARANDA', 'COLON',
#        'LA TRINIDAD', 'CIUDAD TECHO', 'LOS ANGELES', 'EL PROGRESO',
#        'LA CHUCUA', 'SANTA CATALINA', 'EL RUBI', 'LAGO TIMIZA I',
#        'TIMIZA A', 'ALOHA SECTOR SUR', 'BOSQUE DE MODELIA', 'LUSITANIA',
#        'JARDIN BOTANICO', 'BAVARIA', 'VILLA CLAUDIA', 'LA ISABELA',
#        'LA TRIGUERA', 'LA IGUALDAD', 'HIPOTECHO', 'HIPOTECHO II',
#        'HIPOTECHO III', 'CENTRO AMERICAS', 'MANDALAY II', 'BELMIRA',
#        'GIRALDA', 'EL LAUREL', 'SIERRAS DEL MORAL', 'SIERRAS DE MORAL',
#        'CONTADOR', 'CEDRO SALAZAR', 'CEDRO GOLF', 'LOMBARDIA',
#        'LA EMILIA', 'CEDRO BOLIVAR', 'PARQUES DE LORENA',
#        'EL CONTADOR-USAQUÉN', 'EL CONTADOR', 'EL CEDRO', 'LOS CEDRITOS',
#        'CEDRITOS', 'ACACIAS USAQUEN', 'VILLA DORADO NORTE', 'POTOSI',
#        'JERUSALEN', 'BELLAVISTA', 'SAN CARLOS', 'GUSTAVO RESTREPO',
#        'OLAYA', 'SAN FRANCISCO', 'LAS ACACIAS', 'LA AURORA', 'TORCA',
#        'EL MORAL', 'COUNTRY CLUB', 'SAN CRISTOBAL NORTE', 'BARRANCAS',
#        'BARRANCAS NORTE', 'LA PATRIA', 'USAQUEN', 'SANTA ANA OCCIDENTAL',
#        'SANTA BARBARA ORIENTAL', 'SANTA ANA ORIENTAL', 'BELLA SUIZA',
#        'GINEBRA', 'ESCUELA DE INFANTERIA', 'RINCON DEL CHICO',
#        'SAN BASILIO', 'ALAMOS', 'ALAMOS NORTE', 'BOSQUES DE MARIANA',
#        'LIBANO', 'VILLAS DE GRANADA', 'VILLAS DE GRANADA I', 'EL MORTIÑO',
#        'GRAN GRANADA', 'CLUB LOS LAGARTOS', 'QUINTA CAMACHO',
#        'LA PORCIUNCULA', 'PORCIUNCULA', 'ESPARTILLAL', 'EL ESPARTILLAL',
#        'LA CABRERA', 'VILLA INES', 'CHICO', 'EL CHICO', 'ANTIGUO COUNTRY',
#        'CHICO NORTE II', 'CHICO NORTE', 'CHICÓ NORTE', 'CHICO NORTE III',
#        'CHICO NORTE II SECTOR', 'CHICO NORTE III SECTOR', 'QUINTA MUTIS',
#        'BAQUERO', 'BENJAMIN HERRERA', 'CONCEPCION NORTE',
#        'SIETE DE AGOSTO', 'ALCAZARES', 'COLOMBIA', '0', 'SAN FELIPE',
#        'ALCAZARES NORTE', 'JUAN XXIII', 'POLO CLUB', 'EL DORADO',
#        'GIRARDOT', 'LAS AGUAS', 'BOSQUE IZQUIERDO', 'LA PERSEVERANCIA',
#        'BELEN', 'SANTA BARBARA', 'SANTA BARBARA ALTA',
#        'SANTA BARBARA CENTRAL', 'EGIPTO', 'VILLA SAGRARIO', 'LA CATEDRAL',
#        'SIMON BOLIVAR', 'EL ROSARIO', 'H.B.', 'EL TRIUNFO',
#        'LAS MERCEDES', 'SAN ANTONIO NORTE', 'LOS CEDROS-USAQUÉN',
#        'SANTA MARIA', 'COLINA', 'EL CODITO', 'TIBABITA', 'EL RINCON',
#        'VILLA ELISA', 'LOS ROSALES', 'BOYACA', 'SANTA HELENITA',
#        'JOSE JOAQUIN VARGAS', 'FLORIDA BLANCA', 'LA FLORIDA', 'LA GRANJA',
#        'CARVAJAL', 'CIUDAD BERNA', 'CARACAS', 'SEVILLA',
#        'CIUDAD JARDIN SUR', 'LA CONCORDIA', 'RESTREPO', 'SANTANDER',
#        'LA FRAGUITA', 'LA FRAGUA', 'OSPINA PEREZ SUR', 'MUZU',
#        'AUTOPISTA MUZU', 'LA ALQUERIA', 'SANTA MATILDE', 'LA ASUNCION',
#        'REMANSO SUR', 'BOCHICA', 'VERAGUAS', 'SAN EUSEBIO', 'TIBANA',
#        'LA CAMELIA', 'PRIMAVERA OCCIDENTAL', '20 DE JULIO', 'ATENAS',
#        'SAN ISIDRO', 'EL PORTAL', 'MARSELLA', 'LA INDEPENDENCIA',
#        'ESCOCIA', 'BRASILIA', 'LA LIBERTAD', 'LAS AMERICAS', 'LOS ANDES',
#        'NUEVA GRANADA', 'LA CAPILLA', 'JOSE ANTONIO GALAN', 'EL JARDIN',
#        'LA ESMERALDA', 'LAS CRUCES', 'SAN BERNARDO', 'EL CEREZO',
#        'EL TINTAL', 'EL TINTAL CENTRAL', 'EL RINCON DE LOS ANGELES',
#        'NUEVO KENNEDY', 'URBANIZACION CASTILLA', 'VILLA ALSACIA 2',
#        'VILLA ALSACIA', 'VALLADOLID', 'EL VERGEL OCCIDENTAL',
#        'LA FELICIDAD', 'REMANSO', 'ESTACION VICTORIA', 'LA MAGDALENA',
#        'SABANA GRANDE', 'ZONA FRANCA', 'SAN CAYETANO', 'RAFAEL URIBE',
#        'MARCO FIDEL SUAREZ', 'QUIROGA CENTRAL', 'CATALUNA', 'INGLES',
#        'LIBERTADOR', 'SANTIAGO PEREZ', 'MILLAN', 'SANTA BIBIANA',
#        'INDIA CATALINA', 'TUNJUELITO', 'EL TEJAR', 'CLARET', 'NUEVO MUZU',
#        'EL CONDOR', 'LAGUNETA', 'VILLA MARIA'], dtype=object)

# %%
df_UPZ = pd.merge(df, df_upz, how = 'left', left_on = 'location', right_on = 'pro_location')
df_UPZ
# Out:
#            price  n_rooms  n_bath  surface  \
# 0      1050000.0        3       2     63.0
# 1      3930000.0        3       2    100.0
# 2       750000.0        3       1     90.0
# 3      3400000.0        5       4     71.0
# 4      1560000.0        4       3     96.0
# ...          ...      ...     ...      ...
# 16043   796550.0        1       1     35.0
# 16044  1650000.0        1       1     54.0
# 16045  1550000.0        1       2     56.0
# 16046  3000000.0        1       2     38.0
# 16047  2750000.0        1       2     57.0
#
#                                                  details  \
# 0      Excelente casa cerca de la calle 80 y Avenida ...
# 1      Se arrienda casa bonita totalmente amoblada co...
# 2      CASA DE TRES NIVELES TRES ALCOBAS SALA COMEDOR...
# 3      casa ezquinera excelente ubicacion cinco alcob...
# 4      Excelente casa de tres niveles, buena ubicació...
# ...                                                  ...
# 16043  APARTAESTUDIO EN CEDRITOS   MULTIFAMILIAR UPSA...
# 16044  Apartamento tipo loft, con muy buena luz, sala...
# 16045  ESPECTACULAR DUPLEX, APARTA-ESTUDIO, EXTERIOR,...
# 16046  Arriendo, lindo y confortable apartamento amob...
# 16047  Apartamento de una alcoba.   Edificio Naia (Ca...
#
#                                                      url  metrocuadrado_index  \
# 0      https://www.metrocuadrado.com/inmueble/arriend...                 25.6
# 1      https://www.metrocuadrado.com/inmueble/arriend...                 57.3
# 2      https://www.metrocuadrado.com/inmueble/arriend...                 12.2
# 3      https://www.metrocuadrado.com/inmueble/arriend...                 56.0
# 4      https://www.metrocuadrado.com/inmueble/arriend...                 47.1
# ...                                                  ...                  ...
# 16043  https://www.metrocuadrado.com/inmueble/arriend...                 41.6
# 16044  https://www.metrocuadrado.com/inmueble/arriend...                 64.5
# 16045  https://www.metrocuadrado.com/inmueble/arriend...                 42.2
# 16046  https://www.metrocuadrado.com/inmueble/arriend...                 76.8
# 16047  https://www.metrocuadrado.com/inmueble/arriend...                 81.1
#
#        furnished property_type rent_type                      location  \
# 0          False          Casa  Arriendo              LA SOLEDAD NORTE
# 1           True          Casa  Arriendo   CIUDAD SALITRE SUR-ORIENTAL
# 2          False          Casa  Arriendo  VILLA DE LOS ALPES II SECTOR
# 3          False          Casa  Arriendo                  PARIS GAITAN
# 4          False          Casa  Arriendo           BALCONES DE ORIENTE
# ...          ...           ...       ...                           ...
# 16043      False       Apartam  Arriendo               ACACIAS USAQUEN
# 16044      False       Apartam  Arriendo           NICOLÁS DE FEDERMÁN
# 16045      False       Apartam  Arriendo                  SAN PATRICIO
# 16046       True       Apartam  Arriendo         SANTA BARBARA CENTRAL
# 16047       True       Apartam  Arriendo               CHICO NORTE III
#
#         price by m2 n_garajes  tipo_producto UPlCodigo  UPlTipo  \
# 0      16666.666667         1            0.0       NaN      NaN
# 1      39300.000000         1            1.0       NaN      NaN
# 2       8333.333333         0            1.0       NaN      NaN
# 3      47887.323944         0            0.0     UPZ29      1.0
# 4      16250.000000         1            1.0     UPZ12      1.0
# ...             ...       ...            ...       ...      ...
# 16043  22758.571429         1            0.0     UPZ13      1.0
# 16044  30555.555556         2            6.0    UPZ106      1.0
# 16045  27678.571429         1            6.0     UPZ16      1.0
# 16046  78947.368421         1            0.0     UPZ94      1.0
# 16047  48245.614035         1            6.0     UPZ97      1.0
#
#             UPlNombre       UPlArea           pro_location
# 0                 NaN           NaN                    NaN
# 1                 NaN           NaN                    NaN
# 2                 NaN           NaN                    NaN
# 3      MINUTO DE DIOS  3.732645e+06           PARIS GAITAN
# 4             TOBERIN  2.906631e+06    BALCONES DE ORIENTE
# ...               ...           ...                    ...
# 16043      LOS CEDROS  6.722632e+06        ACACIAS USAQUEN
# 16044    LA ESMERALDA  1.928785e+06    NICOLÁS DE FEDERMÁN
# 16045   SANTA BARBARA  4.586983e+06           SAN PATRICIO
# 16046   LA CANDELARIA  2.060243e+06  SANTA BARBARA CENTRAL
# 16047      CHICO LAGO  4.224476e+06        CHICO NORTE III
#
# [16048 rows x 19 columns]

# %%
df_UPZ['pro_location'].isna().sum()/df_UPZ.shape[0]
# Out:
# 0.11939182452642073

# %%
# 6
df_stdpob = pd.read_csv('data/estadisticas_upz/estadisticas_poblacion.csv')
df_stdpob.drop(['Unnamed: 0', 'nomupz'], inplace=True, axis=1)
df_stdpob
# Out:
#        upz  personas  trabajoinf_ninos_5_17_anos_perc  \
# 0    UPZ11     68430                              0.6
# 1    UPZ12     50037                              1.8
# 2    UPZ13    102981                              0.0
# 3    UPZ18     69961                              0.4
# 4    UPZ19    121158                              0.3
# ..     ...       ...                              ...
# 107  UPZ63     63145                              1.8
# 108  UPZ90     53837                              0.0
# 109  UPZ99     53837                              0.0
# 110  UPZ97     52951                              0.0
# 111  UPZ88     52951                              0.0
#
#      trabajoinfampliado_ninos_5_17_anos_perc  jovenes_14_24_anos_nini_perc  \
# 0                                        3.9                          20.7
# 1                                       16.7                           9.1
# 2                                        3.5                           5.5
# 3                                        7.2                           9.4
# 4                                        8.0                           8.2
# ..                                       ...                           ...
# 107                                      8.5                          25.3
# 108                                     30.2                           8.2
# 109                                     30.2                           8.2
# 110                                     17.0                           4.3
# 111                                     17.0                           4.3
#
#      indice_envegecimiento  jefe_mujer_perc  adultos_mayores_pobres_perc
# 0                     35.2        44.579934                    17.931973
# 1                     54.7        36.279630                     5.420442
# 2                    118.4        33.286852                     3.250000
# 3                     42.7        36.465059                     9.439051
# 4                     59.1        32.887202                     5.406574
# ..                     ...              ...                          ...
# 107                   16.9        46.147748                    44.985942
# 108                   81.4        47.033692                     5.814843
# 109                   81.4        47.033692                     5.814843
# 110                  153.4        44.667815                     5.401917
# 111                  153.4        44.667815                     5.401917
#
# [112 rows x 8 columns]

# %%
df_indsec = pd.read_csv('data/estadisticas_upz/indice_inseguridad.csv')
df_indsec.drop(['Unnamed: 0', 'UPlNombre2'], inplace=True, axis=1)
df_indsec
# Out:
#     UPlCodigo  indice_inseguridad
# 0      UPZ100            0.671141
# 1       UPZ83            0.000000
# 2      UPZ107            2.318841
# 3      UPZ101            3.629032
# 4       UPZ91           13.537118
# ..        ...                 ...
# 113     UPZ42            2.967359
# 114         3           80.000000
# 115         4            0.000000
# 116         5            0.000000
# 117         1           97.916667
#
# [118 rows x 2 columns]

# %%
df_green = pd.read_csv('data/estadisticas_upz/porcentaje_areas_verdes.csv')
df_green['cod_upz'] = 'UPZ' + df_green['cod_upz'].astype(int).astype(str)
df_green.drop(['Unnamed: 0', 'upz'], inplace=True, axis=1)
df_green
# Out:
#     cod_upz  areas_verdes_perc
# 0     UPZ51          58.196667
# 1     UPZ87          85.924848
# 2      UPZ1          83.966495
# 3     UPZ64          85.778144
# 4     UPZ29          37.852289
# ..      ...                ...
# 108   UPZ32          43.425594
# 109   UPZ95           8.989821
# 110  UPZ117           3.855842
# 111    UPZ9          31.543824
# 112   UPZ30          26.656117
#
# [113 rows x 2 columns]

# %%
df_STD = pd.merge(df_UPZ, df_stdpob, how = 'left', left_on = 'UPlCodigo', right_on = 'upz')
df_STD = pd.merge(df_STD, df_indsec, how = 'left', on = 'UPlCodigo')
df_STD = pd.merge(df_STD, df_green, how = 'left', left_on = 'UPlCodigo', right_on = 'cod_upz')
df_STD
# Out:
#            price  n_rooms  n_bath  surface  \
# 0      1050000.0        3       2     63.0
# 1      3930000.0        3       2    100.0
# 2       750000.0        3       1     90.0
# 3      3400000.0        5       4     71.0
# 4      1560000.0        4       3     96.0
# ...          ...      ...     ...      ...
# 16045   796550.0        1       1     35.0
# 16046  1650000.0        1       1     54.0
# 16047  1550000.0        1       2     56.0
# 16048  3000000.0        1       2     38.0
# 16049  2750000.0        1       2     57.0
#
#                                                  details  \
# 0      Excelente casa cerca de la calle 80 y Avenida ...
# 1      Se arrienda casa bonita totalmente amoblada co...
# 2      CASA DE TRES NIVELES TRES ALCOBAS SALA COMEDOR...
# 3      casa ezquinera excelente ubicacion cinco alcob...
# 4      Excelente casa de tres niveles, buena ubicació...
# ...                                                  ...
# 16045  APARTAESTUDIO EN CEDRITOS   MULTIFAMILIAR UPSA...
# 16046  Apartamento tipo loft, con muy buena luz, sala...
# 16047  ESPECTACULAR DUPLEX, APARTA-ESTUDIO, EXTERIOR,...
# 16048  Arriendo, lindo y confortable apartamento amob...
# 16049  Apartamento de una alcoba.   Edificio Naia (Ca...
#
#                                                      url  metrocuadrado_index  \
# 0      https://www.metrocuadrado.com/inmueble/arriend...                 25.6
# 1      https://www.metrocuadrado.com/inmueble/arriend...                 57.3
# 2      https://www.metrocuadrado.com/inmueble/arriend...                 12.2
# 3      https://www.metrocuadrado.com/inmueble/arriend...                 56.0
# 4      https://www.metrocuadrado.com/inmueble/arriend...                 47.1
# ...                                                  ...                  ...
# 16045  https://www.metrocuadrado.com/inmueble/arriend...                 41.6
# 16046  https://www.metrocuadrado.com/inmueble/arriend...                 64.5
# 16047  https://www.metrocuadrado.com/inmueble/arriend...                 42.2
# 16048  https://www.metrocuadrado.com/inmueble/arriend...                 76.8
# 16049  https://www.metrocuadrado.com/inmueble/arriend...                 81.1
#
#        furnished property_type rent_type  ...  personas  \
# 0          False          Casa  Arriendo  ...       NaN
# 1           True          Casa  Arriendo  ...       NaN
# 2          False          Casa  Arriendo  ...       NaN
# 3          False          Casa  Arriendo  ...  156375.0
# 4          False          Casa  Arriendo  ...   50037.0
# ...          ...           ...       ...  ...       ...
# 16045      False       Apartam  Arriendo  ...  102981.0
# 16046      False       Apartam  Arriendo  ...   26685.0
# 16047      False       Apartam  Arriendo  ...  115124.0
# 16048       True       Apartam  Arriendo  ...   22440.0
# 16049       True       Apartam  Arriendo  ...   52951.0
#
#        trabajoinf_ninos_5_17_anos_perc  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  1.1
# 4                                  1.8
# ...                                ...
# 16045                              0.0
# 16046                              0.6
# 16047                              1.5
# 16048                              0.2
# 16049                              0.0
#
#       trabajoinfampliado_ninos_5_17_anos_perc  jovenes_14_24_anos_nini_perc  \
# 0                                         NaN                           NaN
# 1                                         NaN                           NaN
# 2                                         NaN                           NaN
# 3                                         0.8                          12.6
# 4                                        16.7                           9.1
# ...                                       ...                           ...
# 16045                                     3.5                           5.5
# 16046                                    25.1                           4.1
# 16047                                     2.0                           5.2
# 16048                                     9.3                          16.7
# 16049                                    17.0                           4.3
#
#       indice_envegecimiento  jefe_mujer_perc adultos_mayores_pobres_perc  \
# 0                       NaN              NaN                         NaN
# 1                       NaN              NaN                         NaN
# 2                       NaN              NaN                         NaN
# 3                      71.1        37.073314                    8.406360
# 4                      54.7        36.279630                    5.420442
# ...                     ...              ...                         ...
# 16045                 118.4        33.286852                    3.250000
# 16046                 144.6        31.737793                    2.498345
# 16047                 127.3        38.443910                    3.840225
# 16048                  91.2        40.729156                   16.182676
# 16049                 153.4        44.667815                    5.401917
#
#        indice_inseguridad cod_upz areas_verdes_perc
# 0                     NaN     NaN               NaN
# 1                     NaN     NaN               NaN
# 2                     NaN     NaN               NaN
# 3                1.029160   UPZ29         37.852289
# 4                3.166227   UPZ12         32.395663
# ...                   ...     ...               ...
# 16045            0.782269   UPZ13         35.573427
# 16046            0.000000  UPZ106         27.645824
# 16047            1.161103   UPZ16         25.466350
# 16048            3.383459   UPZ94         18.205454
# 16049            2.047782   UPZ97         20.901367
#
# [16050 rows x 30 columns]

# %%
df_STD[df_STD.columns[8:]]
# Out:
#       property_type rent_type                      location   price by m2  \
# 0              Casa  Arriendo              LA SOLEDAD NORTE  16666.666667
# 1              Casa  Arriendo   CIUDAD SALITRE SUR-ORIENTAL  39300.000000
# 2              Casa  Arriendo  VILLA DE LOS ALPES II SECTOR   8333.333333
# 3              Casa  Arriendo                  PARIS GAITAN  47887.323944
# 4              Casa  Arriendo           BALCONES DE ORIENTE  16250.000000
# ...             ...       ...                           ...           ...
# 16045       Apartam  Arriendo               ACACIAS USAQUEN  22758.571429
# 16046       Apartam  Arriendo           NICOLÁS DE FEDERMÁN  30555.555556
# 16047       Apartam  Arriendo                  SAN PATRICIO  27678.571429
# 16048       Apartam  Arriendo         SANTA BARBARA CENTRAL  78947.368421
# 16049       Apartam  Arriendo               CHICO NORTE III  48245.614035
#
#       n_garajes  tipo_producto UPlCodigo  UPlTipo       UPlNombre  \
# 0             1            0.0       NaN      NaN             NaN
# 1             1            1.0       NaN      NaN             NaN
# 2             0            1.0       NaN      NaN             NaN
# 3             0            0.0     UPZ29      1.0  MINUTO DE DIOS
# 4             1            1.0     UPZ12      1.0         TOBERIN
# ...         ...            ...       ...      ...             ...
# 16045         1            0.0     UPZ13      1.0      LOS CEDROS
# 16046         2            6.0    UPZ106      1.0    LA ESMERALDA
# 16047         1            6.0     UPZ16      1.0   SANTA BARBARA
# 16048         1            0.0     UPZ94      1.0   LA CANDELARIA
# 16049         1            6.0     UPZ97      1.0      CHICO LAGO
#
#             UPlArea  ...  personas trabajoinf_ninos_5_17_anos_perc  \
# 0               NaN  ...       NaN                             NaN
# 1               NaN  ...       NaN                             NaN
# 2               NaN  ...       NaN                             NaN
# 3      3.732645e+06  ...  156375.0                             1.1
# 4      2.906631e+06  ...   50037.0                             1.8
# ...             ...  ...       ...                             ...
# 16045  6.722632e+06  ...  102981.0                             0.0
# 16046  1.928785e+06  ...   26685.0                             0.6
# 16047  4.586983e+06  ...  115124.0                             1.5
# 16048  2.060243e+06  ...   22440.0                             0.2
# 16049  4.224476e+06  ...   52951.0                             0.0
#
#        trabajoinfampliado_ninos_5_17_anos_perc  jovenes_14_24_anos_nini_perc  \
# 0                                          NaN                           NaN
# 1                                          NaN                           NaN
# 2                                          NaN                           NaN
# 3                                          0.8                          12.6
# 4                                         16.7                           9.1
# ...                                        ...                           ...
# 16045                                      3.5                           5.5
# 16046                                     25.1                           4.1
# 16047                                      2.0                           5.2
# 16048                                      9.3                          16.7
# 16049                                     17.0                           4.3
#
#        indice_envegecimiento  jefe_mujer_perc  adultos_mayores_pobres_perc  \
# 0                        NaN              NaN                          NaN
# 1                        NaN              NaN                          NaN
# 2                        NaN              NaN                          NaN
# 3                       71.1        37.073314                     8.406360
# 4                       54.7        36.279630                     5.420442
# ...                      ...              ...                          ...
# 16045                  118.4        33.286852                     3.250000
# 16046                  144.6        31.737793                     2.498345
# 16047                  127.3        38.443910                     3.840225
# 16048                   91.2        40.729156                    16.182676
# 16049                  153.4        44.667815                     5.401917
#
#        indice_inseguridad  cod_upz  areas_verdes_perc
# 0                     NaN      NaN                NaN
# 1                     NaN      NaN                NaN
# 2                     NaN      NaN                NaN
# 3                1.029160    UPZ29          37.852289
# 4                3.166227    UPZ12          32.395663
# ...                   ...      ...                ...
# 16045            0.782269    UPZ13          35.573427
# 16046            0.000000   UPZ106          27.645824
# 16047            1.161103    UPZ16          25.466350
# 16048            3.383459    UPZ94          18.205454
# 16049            2.047782    UPZ97          20.901367
#
# [16050 rows x 22 columns]

# %%
df_STD['Densidad'] = df_STD['personas']/df_STD['UPlArea']

# %%
df_STD
# Out:
#            price  n_rooms  n_bath  surface  \
# 0      1050000.0        3       2     63.0
# 1      3930000.0        3       2    100.0
# 2       750000.0        3       1     90.0
# 3      3400000.0        5       4     71.0
# 4      1560000.0        4       3     96.0
# ...          ...      ...     ...      ...
# 16045   796550.0        1       1     35.0
# 16046  1650000.0        1       1     54.0
# 16047  1550000.0        1       2     56.0
# 16048  3000000.0        1       2     38.0
# 16049  2750000.0        1       2     57.0
#
#                                                  details  \
# 0      Excelente casa cerca de la calle 80 y Avenida ...
# 1      Se arrienda casa bonita totalmente amoblada co...
# 2      CASA DE TRES NIVELES TRES ALCOBAS SALA COMEDOR...
# 3      casa ezquinera excelente ubicacion cinco alcob...
# 4      Excelente casa de tres niveles, buena ubicació...
# ...                                                  ...
# 16045  APARTAESTUDIO EN CEDRITOS   MULTIFAMILIAR UPSA...
# 16046  Apartamento tipo loft, con muy buena luz, sala...
# 16047  ESPECTACULAR DUPLEX, APARTA-ESTUDIO, EXTERIOR,...
# 16048  Arriendo, lindo y confortable apartamento amob...
# 16049  Apartamento de una alcoba.   Edificio Naia (Ca...
#
#                                                      url  metrocuadrado_index  \
# 0      https://www.metrocuadrado.com/inmueble/arriend...                 25.6
# 1      https://www.metrocuadrado.com/inmueble/arriend...                 57.3
# 2      https://www.metrocuadrado.com/inmueble/arriend...                 12.2
# 3      https://www.metrocuadrado.com/inmueble/arriend...                 56.0
# 4      https://www.metrocuadrado.com/inmueble/arriend...                 47.1
# ...                                                  ...                  ...
# 16045  https://www.metrocuadrado.com/inmueble/arriend...                 41.6
# 16046  https://www.metrocuadrado.com/inmueble/arriend...                 64.5
# 16047  https://www.metrocuadrado.com/inmueble/arriend...                 42.2
# 16048  https://www.metrocuadrado.com/inmueble/arriend...                 76.8
# 16049  https://www.metrocuadrado.com/inmueble/arriend...                 81.1
#
#        furnished property_type rent_type  ... trabajoinf_ninos_5_17_anos_perc  \
# 0          False          Casa  Arriendo  ...                             NaN
# 1           True          Casa  Arriendo  ...                             NaN
# 2          False          Casa  Arriendo  ...                             NaN
# 3          False          Casa  Arriendo  ...                             1.1
# 4          False          Casa  Arriendo  ...                             1.8
# ...          ...           ...       ...  ...                             ...
# 16045      False       Apartam  Arriendo  ...                             0.0
# 16046      False       Apartam  Arriendo  ...                             0.6
# 16047      False       Apartam  Arriendo  ...                             1.5
# 16048       True       Apartam  Arriendo  ...                             0.2
# 16049       True       Apartam  Arriendo  ...                             0.0
#
#        trabajoinfampliado_ninos_5_17_anos_perc jovenes_14_24_anos_nini_perc  \
# 0                                          NaN                          NaN
# 1                                          NaN                          NaN
# 2                                          NaN                          NaN
# 3                                          0.8                         12.6
# 4                                         16.7                          9.1
# ...                                        ...                          ...
# 16045                                      3.5                          5.5
# 16046                                     25.1                          4.1
# 16047                                      2.0                          5.2
# 16048                                      9.3                         16.7
# 16049                                     17.0                          4.3
#
#        indice_envegecimiento jefe_mujer_perc  adultos_mayores_pobres_perc  \
# 0                        NaN             NaN                          NaN
# 1                        NaN             NaN                          NaN
# 2                        NaN             NaN                          NaN
# 3                       71.1       37.073314                     8.406360
# 4                       54.7       36.279630                     5.420442
# ...                      ...             ...                          ...
# 16045                  118.4       33.286852                     3.250000
# 16046                  144.6       31.737793                     2.498345
# 16047                  127.3       38.443910                     3.840225
# 16048                   91.2       40.729156                    16.182676
# 16049                  153.4       44.667815                     5.401917
#
#       indice_inseguridad  cod_upz areas_verdes_perc  Densidad
# 0                    NaN      NaN               NaN       NaN
# 1                    NaN      NaN               NaN       NaN
# 2                    NaN      NaN               NaN       NaN
# 3               1.029160    UPZ29         37.852289  0.041894
# 4               3.166227    UPZ12         32.395663  0.017215
# ...                  ...      ...               ...       ...
# 16045           0.782269    UPZ13         35.573427  0.015319
# 16046           0.000000   UPZ106         27.645824  0.013835
# 16047           1.161103    UPZ16         25.466350  0.025098
# 16048           3.383459    UPZ94         18.205454  0.010892
# 16049           2.047782    UPZ97         20.901367  0.012534
#
# [16050 rows x 31 columns]

# %% [markdown]
# ## P2

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
sinplot()

# %%
#1
def estilo(sty = "whitegrid"):
    param = {'axes.facecolor': 'white',
             'axes.edgecolor': 'black',
             'axes.grid': True,
             'axes.axisbelow': 'line',
             'axes.labelcolor': 'black',
             'figure.facecolor': (1, 1, 1, 0),
             'grid.color': '#b0b0b0',
             'grid.linestyle': '-',
             'text.color': 'black',
             'xtick.color': 'red',
             'ytick.color': 'black',
             'xtick.direction': 'out',
             'ytick.direction': 'out',
             'lines.solid_capstyle': 'projecting',
             'patch.edgecolor': 'black',
             'image.cmap': 'viridis',
             'font.family': ['sans-serif'],
             'font.sans-serif': ['DejaVu Sans',
             'Bitstream Vera Sans',
             'Computer Modern Sans Serif',
             'Lucida Grande',
             'Verdana',
             'Geneva',
             'Lucid',
             'Arial',
             'Helvetica',
             'Avant Garde',
             'sans-serif'],
             'patch.force_edgecolor': False,
             'xtick.bottom': True,
             'xtick.top': False,
             'ytick.left': True,
             'ytick.right': False,
             'axes.spines.left': True,
             'axes.spines.bottom': True,
             'axes.spines.right': False,
             'axes.spines.top': False}
    sns.set_style(sty, param)

estilo()
sinplot()

# %%
[print(df_STD.columns[i]) for i in range(len(df_STD.columns))]
print()
# Out:
# price
# n_rooms
# n_bath
# surface
# details
# url
# metrocuadrado_index
# furnished
# property_type
# rent_type
# location
# price by m2
# n_garajes
# tipo_producto
# UPlCodigo
# UPlTipo
# UPlNombre
# UPlArea
# pro_location
# upz
# personas
# trabajoinf_ninos_5_17_anos_perc
# trabajoinfampliado_ninos_5_17_anos_perc
# jovenes_14_24_anos_nini_perc
# indice_envegecimiento
# jefe_mujer_perc
# adultos_mayores_pobres_perc
# indice_inseguridad
# cod_upz
# areas_verdes_perc
# Densidad

# %%
property_info = ['price', 'n_rooms', 'n_bath', 'surface', 'metrocuadrado_index', "furnished", "property_type", "rent_type","location", "price by m2", "n_garajes", "UPlCodigo"]

# %%
location_info = ["location", "price by m2", "surface", "UPlCodigo"]

# %%
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        1.0
# 4        1.0
#         ...
# 16045    1.0
# 16046    1.0
# 16047    1.0
# 16048    1.0
# 16049    1.0
# Name: UPlTipo, Length: 16050, dtype: float64
